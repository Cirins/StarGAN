# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/ST/cwru

# %%
# !pip install munch

# %%
# !python main.py --mode train --lambda_ds 0 --lambda_trts 0 --lambda_cyc 100 --lambda_id 100 --lambda_dom 0.1 --dom_start 15000 --dom_iter 5000 --resume_iter 18000
